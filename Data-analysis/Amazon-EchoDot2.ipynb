# %% [markdown]
# exportional data analysis

# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Dataset
import kagglehub

path= kagglehub.dataset_download('PromptCloudHQ/amazon-echo-dot-2-reviews-dataset')

# %%
#List CSV
csv_files=[x for x in os.listdir(path) if x.endswith('.csv')]

#Read the files and joind them in a DataFrame
dataframes=[]

for file in csv_files:
    c= os.path.join(path, file)
    df= pd.read_csv(c)
    dataframes.append(df)

df_f= pd.concat(dataframes, ignore_index=True)

# %%
df_f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6855 entries, 0 to 6854
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Pageurl              6855 non-null   object
#  1   Title                6855 non-null   object
#  2   Review Text          6850 non-null   object
#  3   Review Color         6855 non-null   object
#  4   User Verified        6641 non-null   object
#  5   Review Date          6855 non-null   object
#  6   Review Useful Count  28 non-null     float64
#  7   Configuration Text   6855 non-null   object
#  8   Rating               6855 non-null   int64
#  9   Declaration Text     6 non-null      object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 535.7+ KB

# %%
df_f.head()
# Out:
#                                              Pageurl        Title  \
# 0  https://www.amazon.com/All-New-Amazon-Echo-Dot...  Three Stars
# 1  https://www.amazon.com/All-New-Amazon-Echo-Dot...   Four Stars
# 2  https://www.amazon.com/All-New-Amazon-Echo-Dot...     Awesome!
# 3  https://www.amazon.com/All-New-Amazon-Echo-Dot...   Five Stars
# 4  https://www.amazon.com/All-New-Amazon-Echo-Dot...   Five Stars
#
#           Review Text Review Color      User Verified Review Date  \
# 0  Not great speakers        Black  Verified Purchase   10/3/2017
# 1  Great little gagit        White  Verified Purchase   9/26/2017
# 2          Awesome 👏🏽        White  Verified Purchase    9/8/2017
# 3        Love my Echo        Black  Verified Purchase  10/19/2017
# 4        Great device        Black  Verified Purchase   9/17/2017
#
#    Review Useful Count Configuration Text  Rating Declaration Text
# 0                  NaN           Echo Dot       3              NaN
# ...

# %%
df_f.drop(['Title','Review Text','Review Date','Review Useful Count','Declaration Text'], axis=1)
# Out:
#                                                 Pageurl Review Color  \
# 0     https://www.amazon.com/All-New-Amazon-Echo-Dot...        Black
# 1     https://www.amazon.com/All-New-Amazon-Echo-Dot...        White
# 2     https://www.amazon.com/All-New-Amazon-Echo-Dot...        White
# 3     https://www.amazon.com/All-New-Amazon-Echo-Dot...        Black
# 4     https://www.amazon.com/All-New-Amazon-Echo-Dot...        Black
# ...                                                 ...          ...
# 6850  https://www.amazon.com/All-New-Amazon-Echo-Dot...        Black
# 6851  https://www.amazon.com/All-New-Amazon-Echo-Dot...        White
# 6852  https://www.amazon.com/All-New-Amazon-Echo-Dot...        Black
# 6853  https://www.amazon.com/All-New-Amazon-Echo-Dot...        Black
# 6854  https://www.amazon.com/All-New-Amazon-Echo-Dot...        Black
#
#           User Verified Configuration Text  Rating
# 0     Verified Purchase           Echo Dot       3
# ...

# %%
df0=df_f.fillna(0)

# %%
df0.describe()
# Out:
#        Review Useful Count       Rating
# count          6855.000000  6855.000000
# mean              0.069730     4.207002
# std               3.815689     1.272551
# min               0.000000     1.000000
# 25%               0.000000     4.000000
# 50%               0.000000     5.000000
# 75%               0.000000     5.000000
# max             284.000000     5.000000

# %%
df0.shape
# Out:
# (6855, 10)

# %% [markdown]
# Data Visualization

# %%
sns.histplot(data=df0['Rating'], color='purple')
plt.title('Rating Count')
plt.show()

# %%
#Frequency Plot
sns.countplot(data=df0, x='Review Color', color='orange')
plt.title('Frequency by Color')
plt.show()

#Pie Plot
freq_color=df0['Review Color'].value_counts()
plt.figure()
plt.pie(freq_color, labels=freq_color.index,
        autopct='%1.2f%%', startangle=90, colors=plt.cm.Set3.colors   
        )
plt.show()

# %%
#Frequency Plot
sns.countplot(data=df0, x='Configuration Text', color='green')
plt.title('Frequency by Configuration Text')
plt.show()

#Pie Plot
freq_config= df0['Configuration Text'].value_counts()
plt.figure()
plt.pie(freq_config, labels=freq_config.index,
        autopct='%1.2f%%', startangle=90, colors=plt.cm.Set3.colors   
        )
plt.show()

# %%
#Frequency Plot
sns.countplot(data=df0, x='User Verified', color='yellow')
plt.title('Frequency by User Verified')
plt.show()

#Pie Plot
freq_user= df0['User Verified'].value_counts()
plt.figure()
plt.pie(freq_user, labels=freq_user.index,
        autopct='%1.2f%%', startangle=90, colors=plt.cm.Set3.colors   
        )
plt.show()
